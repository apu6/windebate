# %%
class Pqueue():
  
  def OrdinaryComparison(a,b):
    if a < b: return -1
    if a == b: return 0
    return 1
  
  def __init__(self, comparator = OrdinaryComparison):
    self.cmpfunc = comparator
    self.list=[]
    self.size=0
    
  #def pushUp(self,index):
      #if (self.list[index].cmpfunc(self.list[(index-1)/2])<0):
   #   if (self.cmpfunc(self.list[index],self.list[(index-1)/2])<0):
    #    swap(self.list,index,(index-1)/2)   
    
          
  def swap(self,list,first,second):
    temp=self.list[first]
    self.list[first]=self.list[second]
    self.list[second]=temp
        
  def pushDown(index):
    self.list.pop
    rightChild=2*index+1
    leftChild=2*index
    if (leftChild>=self.size):
      return;
      if (rightChild>=self.size):
        if(self.list[index].cmpfunc(self.list[leftChild])>0):
          swap(self.list,index,leftChild)
          pushDown(leftChild)
      elif (self.list[index].cmpfunc(self.list[leftChild])>0):
        if(self.list[leftChild].cmpfunc(self.list[rightChild])<=0):
          swap(self.list,index,leftChild)
          pushDown(leftChild)
        else:
          swap(self.list,index,rightChild)
          pushDown(rightChild)
      else:
        swap(self.list,index,rightChild)
        pushDown(rightChild)
   
  def push(self,data):
    self.list.append(data)
    lastPos=len(self.list) - 1
    while lastPos >1:
      parent=lastPos/2
      if self.cmpfunc(self.list[(len(self.list)-1)/2,self.list[len(self.list)-1]])==1:
        temp=self.list[len(self.list)-1]
        self.list[len(self.list)-1]=self.list[(len(self.list)-1)/2]
        self.list[(len(self.list)-1)/2]=temp
        lastPos=parent
      else:
        break    
    
  def pop(self):
    if(self.size==0):
      return None
    temp = peek()
    self.list[0]=self.list[self.size-1]
    size-=1
    pushDown(0)
    return temp
  
  def peek(self):
    if(self.size==0):
      return None
    else:
      return self.list[0]

# %%
def my_cmp(a,b):
   if len(a) < len(b): return -1
   if len(a) == len(b): return 0
   return 1
  
Fred = Pqueue(my_cmp)
Fred.push([2,"hello",[4,3]])
Fred.peek()
Fred.pop()
